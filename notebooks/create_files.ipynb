# %%
from google.colab import drive
drive.mount('/content/drive')

project_path = "/content/drive/MyDrive/ML_Projects/3D_MRI_Brain_Tumor"
# Out:
# Mounted at /content/drive

# %%
import os

# %%
# config_path = os.path.join(project_path, "src/config.py")
# os.makedirs(os.path.dirname(config_path), exist_ok=True)

# try:
#     with open(config_path, 'x') as f:
#         pass
#         print(f"Created: {config_path}")
# except FileExistsError:
#     print("File already exists!!")

# %%
# file_path = os.path.join(project_path, "src/dataset.py")
# os.makedirs(os.path.dirname(file_path), exist_ok=True)

# try:
#     with open(file_path, 'x') as f:
#         pass
#         print(f"Created: {file_path}")
# except FileExistsError:
#     print("File already exists!!")

# %%
# file_path = os.path.join(project_path, "src/transforms.py")
# os.makedirs(os.path.dirname(file_path), exist_ok=True)

# try:
#     with open(file_path, 'x') as f:
#         pass
#         print(f"Created: {file_path}")
# except FileExistsError:
#     print("File already exists!!")

# %%
# file_path = os.path.join(project_path, "src/losses.py")
# os.makedirs(os.path.dirname(file_path), exist_ok=True)

# try:
#     with open(file_path, 'x') as f:
#         pass
#         print(f"Created: {file_path}")
# except FileExistsError:
#     print("File already exists!!")

# %%
# file_path = os.path.join(project_path, "src/metrics.py")
# os.makedirs(os.path.dirname(file_path), exist_ok=True)

# try:
#     with open(file_path, 'x') as f:
#         pass
#         print(f"Created: {file_path}")
# except FileExistsError:
#     print("File already exists!!")

# %%
# file_path = os.path.join(project_path, "src/models/mamba_backbone.py")
# os.makedirs(os.path.dirname(file_path), exist_ok=True)

# try:
#     with open(file_path, 'x') as f:
#         pass
#         print(f"Created: {file_path}")
# except FileExistsError:
#     print("File already exists!!")

# %%
# file_path = os.path.join(project_path, "src/models/fusion.py")
# os.makedirs(os.path.dirname(file_path), exist_ok=True)

# try:
#     with open(file_path, 'x') as f:
#         pass
#         print(f"Created: {file_path}")
# except FileExistsError:
#     print("File already exists!!")

# %%
# file_path = os.path.join(project_path, "src/models/decoder.py")
# os.makedirs(os.path.dirname(file_path), exist_ok=True)

# try:
#     with open(file_path, 'x') as f:
#         pass
#         print(f"Created: {file_path}")
# except FileExistsError:
#     print("File already exists!!")

# %%
# file_path = os.path.join(project_path, "src/models/classification.py")
# os.makedirs(os.path.dirname(file_path), exist_ok=True)

# try:
#     with open(file_path, 'x') as f:
#         pass
#         print(f"Created: {file_path}")
# except FileExistsError:
#     print("File already exists!!")

# %%
# file_path = os.path.join(project_path, "src/engine.py")
# os.makedirs(os.path.dirname(file_path), exist_ok=True)

# try:
#     with open(file_path, 'x') as f:
#         pass
#         print(f"Created: {file_path}")
# except FileExistsError:
#     print("File already exists!!")
# Out:
# Created: /content/drive/MyDrive/ML_Projects/3D_MRI_Brain_Tumor/src/engine.py
