# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
project_path = "/content/drive/MyDrive/ML_Projects/3D_MRI_Brain_Tumor"

# %%
# %cd /content/drive/MyDrive/ML_Projects/3D_MRI_Brain_Tumor
# Out:
# /content/drive/MyDrive/ML_Projects/3D_MRI_Brain_Tumor

# %%
# !ls -a
# Out:
# checkpoints  data  .env  .git  .gitignore  notebooks  src

# %%
# !mv .gitignore.txt .gitignore

# %%
# # *********************1st time only*********************
# !git init

# %%
# # *********************1st time only*********************
# !git branch -M main

# %%
# !git config --global user.email "shatin.hasan73@gmail.com"
# !git config --global user.name "Nobobi-Hasan"

# %%
# # *********************1st time only*********************
# !git remote add origin https://github.com/Nobobi-Hasan/3D_MRI_BT.git

# %%
# # *********************1st time only*********************
# !git config --global credential.helper store

# %%
# !git add .

# %%
# !git commit -m "Save separate best_mean_dice, best_macro_f1, and best_combined_score from engine.py."
# Out:
# [main 34123fd] combined_score for best metrics calculation in engine.py.
#  3 files changed, 20 insertions(+), 16 deletions(-)
#  rewrite notebooks/git.ipynb (100%)

# %%
# # if GITHUB_TOKEN changed

# from dotenv import load_dotenv
# import os
# load_dotenv()

# # read existing file
# with open(".env", "r") as f:
#     lines = f.readlines()

# # update only GITHUB_TOKEN line
# with open(".env", "w") as f:
#     for line in lines:
#         if line.startswith("GITHUB_TOKEN="):
#             f.write("GITHUB_TOKEN=token_here\n")
#             print('Found and replaces')
#         else:
#             f.write(line)

# %%
from dotenv import load_dotenv
import os

load_dotenv(override=True)

token = os.getenv("GITHUB_TOKEN")
print(token[:5])  # just to verify (safe partial print)
# Out:
# githu

# %%
# !git push https://{token}@github.com/Nobobi-Hasan/3D_MRI_BT.git main
# Out:
# Enumerating objects: 13, done.
# Counting objects: 100% (13/13), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 1.53 KiB | 260.00 KiB/s, done.
# Total 7 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/Nobobi-Hasan/3D_MRI_BT.git
#    12e5a5f..34123fd  main -> main

# %%
with open(".env", "r") as f:
    for line in f:
        key = line.split("=")[0]
        print(key + ' = *****')
# Out:
# GITHUB_TOKEN = *****
