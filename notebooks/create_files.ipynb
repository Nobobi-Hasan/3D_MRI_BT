# %%
from google.colab import drive
drive.mount('/content/drive')

project_path = "/content/drive/MyDrive/ML_Projects/3D_MRI_Brain_Tumor"
# Out:
# Mounted at /content/drive

# %%
import os

# %%
# evaluation_path = os.path.join(project_path, "src/evaluation.py")
# os.makedirs(os.path.dirname(evaluation_path), exist_ok=True)

# try:
#     with open(evaluation_path, 'x') as f:
#         pass
#         print(f"Created: {evaluation_path}")
# except FileExistsError:
#     print("File already exists!!")
